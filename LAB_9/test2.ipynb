# %%
import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
import numpy as np

# Load MNIST dataset and preprocess
from keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images, test_images = train_images / 255.0, test_images / 255.0


# One-hot encode labels
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

    # Reshape images to (28, 28, 1) for Conv2D layer
train_images_reshaped = train_images.reshape((-1, 28, 28, 1))
test_images_reshaped = test_images.reshape((-1, 28, 28, 1))

# %%
print(train_images_reshaped.shape)
print("*"*20)
print(train_labels.shape)
print("*"*20)
print(test_images_reshaped.shape)
print(test_labels.shape)
# Out:
# (60000, 28, 28, 1)
# ********************
# (60000, 10)
# ********************
# (10000, 28, 28, 1)
# (10000, 10)

# %%
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from keras import models
from keras.optimizers import Adam, SGD
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout, Activation, BatchNormalization

# Function to create and train the specified CNN model
def create_and_train_model():
    
     model=Sequential()
     model.add(Conv2D(28,(5,5),padding='same',input_shape=train_images_reshaped.shape[1:]))
     model.add(Activation('relu'))
     model.add(BatchNormalization())
     model.add(Conv2D(28,(5,5)))
     model.add(Activation('relu'))
     model.add(MaxPool2D(pool_size=(2,2)))
     model.add(Dropout(0.25))
     model.add(Conv2D(32,(5,5),padding='same',input_shape=train_images_reshaped.shape[1:]))
     model.add(Activation('relu'))
     model.add(BatchNormalization())
     model.add(Conv2D(32,(5,5)))
     model.add(Activation('relu'))
     model.add(MaxPool2D(pool_size=(2,2)))
     model.add(Dropout(0.25))
     model.add(Flatten())
     model.add(Dense(512))
     model.add(Activation('relu'))
     model.add(Dropout(0.25))
     model.add(Dense(10))
     model.add(Activation('softmax'))


    # Compile the model
     model.compile(optimizer=SGD(learning_rate=0.01), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

#     # Reshape images to (28, 28, 1) for Conv2D layer
#      train_images_reshaped = train_images.reshape((-1, 28, 28, 1))
#      test_images_reshaped = test_images.reshape((-1, 28, 28, 1))

    # Train the model
     history = model.fit(train_images_reshaped, train_labels, 
                        epochs=10, batch_size=64, 
                        validation_split=0.2, verbose=1)
    
    # Evaluate the model on the test set
     test_loss, test_accuracy = model.evaluate(test_images_reshaped, test_labels, verbose=2)

     return test_accuracy


num_models = 5
test_accuracies = []

for i in range(num_models):
    acurracy = create_and_train_model()
    test_accuracies.append(acurracy)
    print(f'Model-{i+1} test accuracy: {acurracy:.4f}')

# Compute the mean test accuracy
mean_test_accuracy = np.mean(test_accuracies)
print(f'Mean Test Accuracy across Models: {mean_test_accuracy}')
# Out:
# Epoch 1/10
# 750/750 [==============================] - 66s 87ms/step - loss: 0.3357 - accuracy: 0.8940 - val_loss: 0.0811 - val_accuracy: 0.9752
# Epoch 2/10
# 750/750 [==============================] - 72s 96ms/step - loss: 0.1191 - accuracy: 0.9622 - val_loss: 0.0571 - val_accuracy: 0.9824
# Epoch 3/10
# 750/750 [==============================] - 77s 103ms/step - loss: 0.0872 - accuracy: 0.9718 - val_loss: 0.0512 - val_accuracy: 0.9835
# Epoch 4/10
# 750/750 [==============================] - 76s 101ms/step - loss: 0.0711 - accuracy: 0.9774 - val_loss: 0.0444 - val_accuracy: 0.9876
# Epoch 5/10
# 750/750 [==============================] - 80s 107ms/step - loss: 0.0617 - accuracy: 0.9804 - val_loss: 0.0427 - val_accuracy: 0.9879
# Epoch 6/10
# 750/750 [==============================] - 85s 113ms/step - loss: 0.0566 - accuracy: 0.9826 - val_loss: 0.0371 - val_accuracy: 0.9889
# Epoch 7/10
# 750/750 [==============================] - 69s 92ms/step - loss: 0.0525 - accuracy: 0.9835 - val_loss: 0.0347 - val_accuracy: 0.9900
# Epoch 8/10
# 750/750 [==============================] - 77s 103ms/step - loss: 0.0470 - accuracy: 0.9849 - val_loss: 0.0369 - val_accuracy: 0.9888
# Epoch 9/10
# 750/750 [==============================] - 69s 92ms/step - loss: 0.0439 - accuracy: 0.9864 - val_loss: 0.0403 - val_accuracy: 0.9874
# Epoch 10/10
# 750/750 [==============================] - 73s 98ms/step - loss: 0.0397 - accuracy: 0.9876 - val_loss: 0.0361 - val_accuracy: 0.9893
# 313/313 - 5s - loss: 0.0225 - accuracy: 0.9931 - 5s/epoch - 15ms/step
# Model-1 test accuracy: 0.9931
# Epoch 1/10
# 750/750 [==============================] - 83s 109ms/step - loss: 0.3649 - accuracy: 0.8830 - val_loss: 0.0787 - val_accuracy: 0.9765
# Epoch 2/10
# 750/750 [==============================] - 70s 93ms/step - loss: 0.1150 - accuracy: 0.9648 - val_loss: 0.0620 - val_accuracy: 0.9807
# Epoch 3/10
# 750/750 [==============================] - 83s 111ms/step - loss: 0.0875 - accuracy: 0.9734 - val_loss: 0.0485 - val_accuracy: 0.9854
# Epoch 4/10
# 750/750 [==============================] - 87s 116ms/step - loss: 0.0728 - accuracy: 0.9773 - val_loss: 0.0412 - val_accuracy: 0.9871
# Epoch 5/10
# 750/750 [==============================] - 76s 102ms/step - loss: 0.0641 - accuracy: 0.9795 - val_loss: 0.0390 - val_accuracy: 0.9876
# Epoch 6/10
# 750/750 [==============================] - 79s 105ms/step - loss: 0.0548 - accuracy: 0.9823 - val_loss: 0.0390 - val_accuracy: 0.9874
# Epoch 7/10
# 750/750 [==============================] - 76s 102ms/step - loss: 0.0508 - accuracy: 0.9840 - val_loss: 0.0360 - val_accuracy: 0.9891
# Epoch 8/10
# 750/750 [==============================] - 70s 93ms/step - loss: 0.0476 - accuracy: 0.9852 - val_loss: 0.0297 - val_accuracy: 0.9908
# Epoch 9/10
# 750/750 [==============================] - 78s 103ms/step - loss: 0.0431 - accuracy: 0.9862 - val_loss: 0.0304 - val_accuracy: 0.9906
# Epoch 10/10
# Epoch 6/10
# 750/750 [==============================] - 79s 106ms/step - loss: 0.0570 - accuracy: 0.9827 - val_loss: 0.0419 - val_accuracy: 0.9870
# Epoch 7/10
# 750/750 [==============================] - 72s 96ms/step - loss: 0.0511 - accuracy: 0.9839 - val_loss: 0.0340 - val_accuracy: 0.9902
# Epoch 8/10
# 750/750 [==============================] - 73s 98ms/step - loss: 0.0447 - accuracy: 0.9856 - val_loss: 0.0335 - val_accuracy: 0.9900
# Epoch 9/10
# 750/750 [==============================] - 70s 93ms/step - loss: 0.0422 - accuracy: 0.9867 - val_loss: 0.0315 - val_accuracy: 0.9909
# Epoch 10/10
# 750/750 [==============================] - 74s 99ms/step - loss: 0.0392 - accuracy: 0.9872 - val_loss: 0.0322 - val_accuracy: 0.9898
# 313/313 - 4s - loss: 0.0221 - accuracy: 0.9924 - 4s/epoch - 12ms/step
# Model-4 test accuracy: 0.9924
# Epoch 1/10
# 750/750 [==============================] - 71s 94ms/step - loss: 0.3425 - accuracy: 0.8917 - val_loss: 0.0794 - val_accuracy: 0.9771
# Epoch 2/10
# 750/750 [==============================] - 70s 93ms/step - loss: 0.1173 - accuracy: 0.9640 - val_loss: 0.0542 - val_accuracy: 0.9843
# Epoch 3/10
# 750/750 [==============================] - 68s 91ms/step - loss: 0.0888 - accuracy: 0.9726 - val_loss: 0.0464 - val_accuracy: 0.9862
# Epoch 4/10
# 750/750 [==============================] - 64s 86ms/step - loss: 0.0743 - accuracy: 0.9767 - val_loss: 0.0421 - val_accuracy: 0.9862
# Epoch 5/10
# 750/750 [==============================] - 74s 99ms/step - loss: 0.0623 - accuracy: 0.9810 - val_loss: 0.0379 - val_accuracy: 0.9887
# Epoch 6/10
# 750/750 [==============================] - 68s 91ms/step - loss: 0.0562 - accuracy: 0.9821 - val_loss: 0.0388 - val_accuracy: 0.9886
# Epoch 7/10
# 750/750 [==============================] - 71s 94ms/step - loss: 0.0518 - accuracy: 0.9842 - val_loss: 0.0380 - val_accuracy: 0.9882
# Epoch 8/10
# 750/750 [==============================] - 67s 90ms/step - loss: 0.0456 - accuracy: 0.9864 - val_loss: 0.0361 - val_accuracy: 0.9883
# Epoch 9/10
# 750/750 [==============================] - 81s 108ms/step - loss: 0.0439 - accuracy: 0.9862 - val_loss: 0.0343 - val_accuracy: 0.9894
# Epoch 10/10
# 750/750 [==============================] - 80s 106ms/step - loss: 0.0414 - accuracy: 0.9873 - val_loss: 0.0341 - val_accuracy: 0.9896
# 313/313 - 4s - loss: 0.0213 - accuracy: 0.9921 - 4s/epoch - 12ms/step
# Model-5 test accuracy: 0.9921
# Mean Test Accuracy across Models: 0.992579996585846
