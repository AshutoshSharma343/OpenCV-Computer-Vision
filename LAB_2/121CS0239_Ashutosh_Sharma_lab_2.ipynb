# %%
# Install the following libraries
# %pip install opencv-python
# %pip install numpy
# %pip install matplotlib
# print('h')

# %%
# Python code to read image
import cv2
import numpy as np
import matplotlib.pyplot as plt
 
# To read image from disk, we use
# cv2.imread function, in below method,
img_path = r"C:\Users\ashuo\Downloads\GithubProjects\OpenCV-Computer-Vision\LAB_2\lena.jpg"
img = cv2.imread(r"C:\Users\ashuo\Downloads\GithubProjects\OpenCV-Computer-Vision\LAB_2\lena.jpg")
 
# Check if the image is loaded successfully
if img is not None and img.shape[0] > 0 and img.shape[1] > 0:
    # Display the image
    #cv2.imshow("image", img)
    print('success')
else:
    print("Error: Unable to load the image.")
# Out:
# success

# %%
# It is for removing/deleting created GUI window from screen
# and memory
cv2.destroyAllWindows()

# %%
#Displaying image using plt.imshow() method
plt.imshow(img)

# %%
img.shape
# --> 225, 225, 3
print(type(img.shape))

#Height, Width and Channels of the image
# Out:
# <class 'tuple'>

# %%
# Converts the image into a 3D array
img1 = np.array(img)
#print(img1)


# Converts the image into a grayscale image
new_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#making the first 100X100 pixels black
for i in range(0,100):
    for j in range(0,100):
        new_img[i,j]=0
        
plt.imshow(new_img)

# %%
x,y,z=img.shape
x1,y1,z1=img1.shape

# %%
# Assignment: Do it by hardcoding using slicing
# Horizontally Stacking
img4=np.hstack((img,img1))
plt.imshow(img4)

# %%
# Assignment: Do it by hardcoding using slicing
# Vertically Stacking
img5=np.vstack((img,img1))
plt.imshow(img5)

# %%
import cv2
import matplotlib.pyplot as plt

def make_alternate_rows_black(img, k):
    flag = 0
    row, col, cha = img.shape
    for i in range(k, row, k):
        if flag % 2 == 0:
            img[i - k:i, :, 0:3] = 0
        flag = flag + 1

    return img

img = cv2.imread(r"C:\Users\ashuo\Downloads\GithubProjects\OpenCV-Computer-Vision\LAB_2\lena.jpg")
num_rows = 20
result_image = make_alternate_rows_black(img, num_rows)

# OpenCV reads images in BGR format, so we need to convert it to RGB for displaying with matplotlib
result_image_rgb = cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB)

plt.imshow(result_image_rgb)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

def make_alternate_columns_black(img, k):
    flag = 0
    row, col, cha = img.shape
    for j in range(k, col, k):
        if flag % 2 == 0:
            img[:, j - k:j, 0:3] = 0
        flag = flag + 1

    return img

img = cv2.imread(r"C:\Users\ashuo\Downloads\GithubProjects\OpenCV-Computer-Vision\LAB_2\lena.jpg")
num_columns = 20
result_image = make_alternate_columns_black(img, num_columns)

# OpenCV reads images in BGR format, so we need to convert it to RGB for displaying with matplotlib
result_image_rgb = cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB)

plt.imshow(result_image_rgb)
plt.show()

# %% [markdown]
# # ASSIGNMENT-2

# %% [markdown]
# # Question 1

# %%
#method to change the colour value of the first 100*100 pixels of an image to black
def assgn1(image):
    img1=np.array(image)
    for i in range(0,100,1):
        for j in range (0,100,1):
            img1[i,j,:]=0
    
    return img1;    

    
# Converting 100X100X3 pixels into Black
image = cv2.imread(img_path)

res_image = assgn1(image)

plt.imshow(res_image)

# %% [markdown]
# # Question 2

# %%
import cv2
import numpy as np

def assgn2(image1, image2):

    if image1 is None or image2 is None:
        print("Error: Unable to load images.")
        return

    # Get the dimensions of the images
    height1, width1 = image1.shape[:2]
    height2, width2 = image2.shape[:2]

    # Make sure both images have the same height
    if height1 != height2:
        print("Error: Images must have the same height for concatenation.")
        return

    # Create a new image with double the width for concatenation
    combined_image = np.zeros((height1, width1 + width2, 3), dtype=np.uint8)

    # Copy the first image to the left side of the new image
    combined_image[:, :width1, :] = image1

    # Copy the second image to the right side of the new image
    combined_image[:, width1:, :] = image2
    
    return combined_image


image1 = cv2.imread(img_path)
#image2 = cv2.imread(r"C:\Users\Admin\Downloads\anime_lena.jpg")

result_image = assgn2(image1,res_image)

plt.imshow(result_image)

# %% [markdown]
# # QUESTION3

# %%
def assgn3(original_image, x, y, width, height):
   
    # Check if the image is loaded successfully
    if original_image is None:
        print("Error: Unable to load the image.")
        return

    # Extract the specified region using slicing
    extracted_region = original_image[y:y+height, x:x+width]

    # Display the original image
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')

    # Display the extracted region
    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(extracted_region, cv2.COLOR_BGR2RGB))
    plt.title('Extracted Region')

    # Show the plots
    plt.show()

image1 = cv2.imread(r"C:\Users\Admin\Downloads\lena.jpg")
x, y, width, height = 100, 50, 200, 150  # Example coordinates for the region

assgn3(image, x, y, width, height)

# %% [markdown]
# # Question 4  Implement a Python script that reads an image and calculates and plots the histogram of its grayscale version. Save the histogram plot as an image file

# %%
def assgn4(original_image,output_path):

    # Check if the image is loaded successfully
    if original_image is None:
        print("Error: Unable to load the image.")
        return

    # Convert the image to grayscale
    grayscale_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

    # Calculate the histogram
    histogram, bins = np.histogram(grayscale_image.flatten(), 256, [0, 256])

    # Plot the histogram
    plt.plot(histogram, color='black')
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
    plt.title('Grayscale Histogram')

    # Save the histogram plot as an image file
    plt.savefig(output_path)

    # Display the original image and histogram plot
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')

    plt.subplot(1, 2, 2)
    plt.imshow(grayscale_image, cmap='gray')
    plt.title('Grayscale Image')
    
    plt.subplot(1, 3, 3)
    plt.bar(bins[:-1], histogram, width=1, color='black')
    plt.title('Histogram Plot')

    plt.show()

image = cv2.imread(img_path)

output_path = r"C:\Users\ashuo\Downloads\GithubProjects\OpenCV-Computer-Vision\LAB_2\histogram_plot.jpg"
assgn4(image, output_path)
# Out:
# C:\Users\ashuo\AppData\Local\Temp\ipykernel_32308\3229326150.py:24: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)
# C:\Users\ashuo\AppData\Local\Temp\ipykernel_32308\3229326150.py:32: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 3, 3)

# %% [markdown]
# # Question 5

# %% [markdown]
# Create a program that reads an image and applies a Gaussian blur to it using the
# filter shown in the image below. Display both the original image and the blurred
# image. (To apply a filter, you have to convolve the filter with the image)

# %%
def assgn5(original_image, output_path, filter_size):
    
    if original_image is None:
        print("Error: Unable to load the image.")
        return

    # Define the Gaussian blur filter
    gaussian_filter = np.array([[1, 2, 1],
                                [2, 4, 2],
                                [1, 2, 1]]) / 8.0

    # Apply the Gaussian blur filter using convolution
    blurred_image = cv2.filter2D(original_image, -1, gaussian_filter)

    # Display the original and blurred images
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')

    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
    plt.title('Blurred Image')

    # Save the blurred image
    cv2.imwrite(output_path, blurred_image)

    # Show the plots
    plt.show()
    

image = cv2.imread(img_path)
filter_size = 3  # Size of the Gaussian blur filter (3x3 in this example)

assgn5(image, output_path, filter_size)

# %%
def convolve(image, kernel):
    # Get the dimensions of the image and kernel
    img_height, img_width = image.shape[:2]
    kernel_height, kernel_width = kernel.shape[:2]

    # Calculate the padding required for the convolution
    pad_height = kernel_height // 2
    pad_width = kernel_width // 2

    # Pad the image
    padded_image = cv2.copyMakeBorder(image, pad_height, pad_height, pad_width, pad_width, cv2.BORDER_CONSTANT)

    # Create an empty output image
    output_image = np.zeros_like(image, dtype=np.float32)

    # Perform convolution
    for y in range(pad_height, img_height + pad_height):
        for x in range(pad_width, img_width + pad_width):
            region = padded_image[y-pad_height:y+pad_height+1, x-pad_width:x+pad_width+1]
            output_image[y-pad_height, x-pad_width] = np.sum(region * kernel)

    return output_image.astype(np.uint8)



def assgn5(original_image, output_path, filter_size):
    
    if original_image is None:
        print("Error: Unable to load the image.")
        return

    # Define the Gaussian blur filter
    gaussian_filter = np.array([[1, 2, 1],
                                [2, 4, 2],
                                [1, 2, 1]]) / 16.0

    blurred_image = convolve(original_image, gaussian_filter)

    # Display the original and blurred images
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')

    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
    plt.title('Blurred Image')

    # Save the blurred image
    cv2.imwrite(output_path, blurred_image)

    # Show the plots
    plt.show()
    

image = cv2.imread(img_path)

filter_size = 3  # Size of the Gaussian blur filter (3x3 in this example)

assgn5(image, output_path, filter_size)

# %% [markdown]
# Convolution involves sliding a kernel (also called a filter or mask) over an input image and computing the sum of the element-wise products of the kernel and the corresponding pixels in the image.

# %%
# Out:
# (156, 156, 3)
